# %% [markdown]
# This notebook is responsible for extracting the plain-text of the TLG corpus and filtering texts according to various little filters, **mostly to exclude poetry, fragments and uncertain texts**.

# %%
# Documenting
from typing import Generator

# OS
import glob
import os.path

# Data
import csv
import lxml.etree as ET
import pandas
from collections import Counter

# Operations
import regex as re
import unicodedata

# UI
import tqdm

# %% [markdown]
# ## Constants

# %%
#PATH = "/home/thibault/Downloads/comp/Diogenes-Resources/xml/tlg/tlg*.xml"
PATH = "patres/tlg*.xml"
MIN_SIZE = 1000 # Number of first words to take
ForbiddenTGs = {
    "tlg0527", "tlg0031"
}

# %% [markdown]
# ## XML parsing

# %%
def normalize(text: str) -> str:
    return unicodedata.normalize("NFKC", re.sub(r"\s{2,}|\n+", " ", text))

cnt = re.compile("\w+")

NS = {"namespaces": {"t": "http://www.tei-c.org/ns/1.0"}}

XSL = """<xsl:stylesheet xmlns:xsl="http://www.w3.org/1999/XSL/Transform"
    xmlns:xs="http://www.w3.org/2001/XMLSchema"
    xmlns:t="http://www.tei-c.org/ns/1.0"
    exclude-result-prefixes="xs"
    version="1.0">
    <xsl:output method="text"/>
    <xsl:template match="t:TEI">
        <xsl:apply-templates select="//t:body" />
    </xsl:template>
    <xsl:template match="t:body">
        <xsl:apply-templates/>
    </xsl:template>
    <xsl:template match="t:label"/>
    <xsl:template match="t:note"/>
    <xsl:template match="t:head"/>
</xsl:stylesheet>"""

XSL = ET.XSLT(ET.fromstring(XSL))

# %% [markdown]
# ## Filtering functions

# %%
def forbidden_author(string) -> bool:
    string = string.lower()
    if "epistula" in string:
        return True
    if "comment" in string:
        return True
    if "scholia" in string:
        return True
    if "lexic" in string:
        return True
    if "acta" in string:
        return True
    if "fragm" in string:
        return True
    if "corpus" in string:
        return True
    if "anonym" in string:
        return True
    if "pseud" in string:
        return True
    if "testam" in string:
        return True
    if "vita" in string:
        return True
    if string.endswith(" et"):
        return True
    if "evangeli" in string:
        return True
    if "floril" in string:
        return True
    if "anthologia" in string:
        return True
    if "paraphras" in string:
        return True
    if "apocal" in string:
        return True
    if "certamen" in string:
        return True
    if "comica adespota" in string:
        return True
    if "commentaria" in string:
        return True
    if "concilia" in string:
        return True
    if "epica adespota" in string:
        return True
    if "etymologicum" in string:
        return True
    if "epistula ecclesiarum" in string:
        return True
    if "gnologium" in string:
        return True
    if "lyrica adespota" in string:
        return True
    if "proverbi" in string:
        return True
    if "oracula" in string:
        return True
    if "periplus" in string:
        return True
    if "incertus" in string:
        return True
    if "socraticorum epistulae" in string:
        return True
    if "socrat" in string:
        return True
    if "[" in string:
        return True
    if "anonym" in string:
        return True
    if "pseudo" in string:
        return True
    if "ps." in string:
        return True
    if "historia" in string:
        return True
    
def is_poetry(xml):
    return len(xml.xpath("//t:l", **NS)) > 0

def has_fragment(xml):
    return len(xml.xpath("//t:div[@type='fragment']", **NS)) > 0

# %% [markdown]
# ## Data wrangling functions

# %%
def get_tg(filename):
    return os.path.basename(filename)[:7]

def rename_author(author):
    return re.sub(r"(\s+\w+\.)", "", author).replace(" et", "")

# %% [markdown]
# ## Data accumulation

# %%
# Output Data
data = []

# Count the number of files we have per textgroup
tgs = Counter([
    get_tg(file)
    for file in glob.glob(PATH)
])

# Statistics
passed = 0
tgcount = Counter()
ignored_authors = set()
    
for file in tqdm.tqdm(glob.glob(PATH)):
    try:
        xml = ET.parse(file)
        tg = get_tg(file)
        author = str(xml.xpath("/t:TEI/t:teiHeader/t:fileDesc/t:titleStmt/t:author/text()", **NS)[0])
        title = xml.xpath("/t:TEI/t:teiHeader/t:fileDesc/t:titleStmt/t:title/text()", **NS)[0]
        
        if tg in ForbiddenTGs:
            passed += 1
            continue
        elif forbidden_author(author):
            ignored_authors.add(author)
            continue
        elif is_poetry(xml):
            #print(f"Ignoring {file} for poetry reason")
            ignored_authors.add(author)
            continue
        elif has_fragment(xml):
            #print(f"Ignoring {file} for fragment reason")
            ignored_authors.add(author)
            continue
            
        rawtext = normalize(str(XSL(xml))).strip()
        tokens = cnt.findall(rawtext)
        
        if len(tokens) < MIN_SIZE:
            passed += 1
            continue

        data.append({
            "file": os.path.basename(file)[:-4],
            "orig_author": author,
            "author": rename_author(str(author)),
            "title": str(title),
            "textgroup": tg,
            "tokens": len(tokens),
            "full-text-raw": rawtext
        })
        tgcount[tg] += 1
    except Exception as E:
        raise E
        passed += 1
        print(f"Failing on {file}")
        continue
print(passed)
print(ignored_authors)
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1654/1654 [00:14<00:00, 117.63it/s]
# 459
# {'Amphilochius Scr. Eccl.', 'Philostorgius Scr. Eccl.', 'Joannes Chrysostomus Scr. Eccl. John Chrysostom', 'Maximus Confessor Theol.', 'Photius Lexicogr., Scr. Eccl. et Theol.', 'Evagrius Scr. Eccl.', 'Arethas Philol. et Scr. Eccl.', 'Theolytus Epic.', 'Theodorus Studites Scr. Eccl. et Theol.'}

# %% [markdown]
# ## Exporting

# %%
df = pandas.DataFrame(data)
print("Before filtering on Title", df.shape)
df = df[~df.title.str.contains("Dub\.|Sp\.|Fragm|Excerpt|(e cod\.)|Suda|recensio|fragm|sp\.|dub\.|(fort\. auctore)|Scholia")]
print("After filtering on Title", df.shape)


df.to_csv("tlg-texts.csv", index=False)
df.head()
# Out:
# Before filtering on Title (1164, 7)
# After filtering on Title (700, 7)
# /tmp/ipykernel_12209/1736975512.py:3: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   df = df[~df.title.str.contains("Dub\.|Sp\.|Fragm|Excerpt|(e cod\.)|Suda|recensio|fragm|sp\.|dub\.|(fort\. auctore)|Scholia")]
#          file                   orig_author                 author  \
# 1  tlg2800008           Basilius Scr. Eccl.               Basilius
# 2  tlg2040052               Basilius Theol.               Basilius
# 3  tlg2017048     Gregorius Nyssenus Theol.     Gregorius Nyssenus
# 4  tlg2022060  Gregorius Nazianzenus Theol.  Gregorius Nazianzenus
# 5  tlg4138090          Ephraem Syrus Theol.          Ephraem Syrus
#
#                          title textgroup  tokens  \
# 1  Homilia in passionem domini   tlg2800    1314
# 2        De baptismo libri duo   tlg2040   20790
# 3          In Basilium fratrem   tlg2017    6134
# 4              Carmina moralia   tlg2022   37978
# 5         Sermo de uirginitate   tlg4138    1690
#
#                                        full-text-raw
# 1  Μέγα μὲν οὐρανὸς δημιούργημα, καὶ τῆς ὁρωμένης...
# 2  Ὁ Κύριος ἡμῶν Ἰησοῦς Χριστὸς, ὁ μονογενὴς Υἱὸς...
# 3  Καλὴν ἐπέθηκεν ὁ Θεὸς τὴν τάξιν ταῖς ἐτησίοις ...
# 4  Παρθενίην στεφάνοις ἀναδήσομεν ἡμετέροισιν, Ἐκ...
# 5  Περὶ παρθενίας καὶ ἁγιασμοῦ ψυχῆς Παῦλος ἀπόστ...

# %%
for x in sorted(df.orig_author.unique()):
    print(x)
# Out:
# Adamantius Theol.
# Alexander Scr. Eccl.
# Alexander Theol.
# Amphilochius Scr. Eccl.
# Antonius Hagiographus Scr. Eccl.
# Asterius Scr. Eccl.
# Asterius Sophista Scr. Eccl.
# Athanasius Theol.
# Barlaam Math., Theol. et Epist.
# Basilius Med. et Scr. Eccl.
# Basilius Scr. Eccl.
# Basilius Theol.
# Clemens Alexandrinus Theol.
# Clemens Romanus Theol. et Clementina
# Cyrillus Scr. Eccl.
# Cyrillus Theol.
# Didymus Caecus Scr. Eccl. Didymus the Blind
# Dio Chrysostomus Soph.
# Ephraem Scr. Eccl.
# Ephraem Syrus Theol.
# Epiphanius Scr. Eccl.
# Eusebius Scr. Eccl. et Theol.
# Eustathius Philol. et Scr. Eccl.
# Eustathius Scr. Eccl. et Theol.
# Evagrius Scr. Eccl.
# Flavius Justinianus Imperator Theol.
# Gregorius Nazianzenus Theol.
# Gregorius Nyssenus Theol.
# Gregorius Thaumaturgus Scr. Eccl.
# Hesychius Scr. Eccl.
# Hippolytus Scr. Eccl.
# Irenaeus Theol.
# Joannes Chrysostomus Scr. Eccl. John Chrysostom
# Joannes Damascenus Scr. Eccl. et Theol. John of Damascus
# Joannes Gramm. et Theol.
# Joannes Theol.
# Julianus Scr. Eccl.
# Leontius Scr. Eccl.
# Marcellus Theol.
# Marcus Diaconus Scr. Eccl.
# Maximus Confessor Theol.
# Nemesius Theol.
# Nicephorus I Scr. Eccl., Hist. et Theol.
# Nicetas Choniates Hist., Scr. Eccl. et Rhet.
# Nicolaus I Mysticus Theol. et Epist.
# Olympiodorus Diaconus Scr. Eccl.
# Origenes Theol.
# Palladius Scr. Eccl.
# Petrus Scr. Eccl. et Theol.
# Polycarpus Scr. Eccl.
# Procopius Rhet. et Scr. Eccl.
# Salaminius Hermias Sozomenus Scr. Eccl.
# Severianus Scr. Eccl.
# Theodoretus Scr. Eccl. et Theol.
# Theodorus Studites Scr. Eccl. et Theol.

# %% [markdown]
# ## Lemmatization
#
# Requires to have set-up `bert-env` virtual environment.

# %%
# !./bert-env/bin/python tag-in-xml.py tlg-texts.csv
# Out:
# tag-in-xml.py:28: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   texts = texts[~texts.title.str.contains("Dub\.|Sp\.|Fragm|Excerpt|(e cod\.)|Suda|recensio|fragm|sp\.|dub\.|(fort\. auctore)|Scholia")]
# 2023-07-25 14:44:49,741 loading file final-model.pt
# 2023-07-25 14:44:53,285 SequenceTagger predicts: Dictionary with 1030 tags: <unk>, O, a-p---na-, v2spma---, u--------, d--------, v-papamn-, r--------, l-s---ma-, n-s---ma-, v3siie---, l-s---nn-, l-s---fg-, n-s---fg-, l-s---mg-, n-s---mg-, v3ppia---, i--------, n-s---mn-, v3saia---, p-p---fd-, v-sppamn-, a-s---mn-, n-p---mg-, c--------, v3saoa---, p-s---mn-, l-s---mn-, v3siia---, v-sapamg-, b--------, p-s---cg-, p-s---fd-, l-p---mg-, a-p---mg-, a-s---ma-, v-sppamg-, v3spia---, a-p---ng-, n-p---ng-, _, v3piie---, l-p---md-, a-p---md-, v-pppamn-, p-p---ma-, l-s---fa-, n-s---fa-, n-p---na-, v3paia---
# 0it [00:00, ?it/s]Passing tlg2062098
# Passing tlg2063005
# Passing tlg4138086
# Passing tlg2042022
# Passing tlg2797035
# Passing tlg2041004
# Passing tlg4138077
# Passing tlg4138056
# Passing tlg4138094
# Passing tlg2022058
# Passing tlg2115042
# Passing tlg1622001
# Passing tlg4138071
# Passing tlg2022022
# Passing tlg2800007
# Passing tlg2062484
# Passing tlg2022025
# Passing tlg2800012
# Passing tlg2062052
# Passing tlg4138015
# Passing tlg2018014
# Passing tlg2914013
# Passing tlg4138091
# Passing tlg4138111
# Passing tlg2017063
# Passing tlg2062049
# Passing tlg4138009
# Passing tlg2017013
# Passing tlg4090115
# Passing tlg4138057
# Passing tlg4090125
# Passing tlg2112004
# Passing tlg2800008
# Passing tlg4138151
# Passing tlg2042027
# Passing tlg2797039
# Passing tlg2797040
# Passing tlg2734022
# Passing tlg2040031
# Passing tlg4090116
# Passing tlg2800006
# Passing tlg2800003
# Passing tlg2797032
# Passing tlg2914001
# Passing tlg2018032
# Passing tlg2062059
# Passing tlg4138027
# Passing tlg4138137
# Passing tlg4138013
# Passing tlg2062374
# Passing tlg2017084
# Passing tlg4138088
# Passing tlg2042024
# Passing tlg2797033
# Passing tlg2598010
# Passing tlg4138019
# Passing tlg2112001
# Passing tlg4138037
# Passing tlg2040061
# Passing tlg4089035
# Passing tlg4138136
# Passing tlg2734018
# Passing tlg2022024
# Passing tlg2914007
# Passing tlg4138002
# Passing tlg4138089
# Passing tlg2102049
# Passing tlg2022012
# Passing tlg2816002
# Passing tlg2017028
# Passing tlg2017004
# Passing tlg2018012
# Passing tlg2112010
# Passing tlg2112008
# Passing tlg4138041
# Passing tlg4138011
# Passing tlg4138119
# Passing tlg4138048
# Passing tlg4138079
# Passing tlg2060002
# Passing tlg4138095
# Passing tlg2797029
# Passing tlg4138060
# Passing tlg4138146
# Passing tlg4138016
# Passing tlg2042052
# Passing tlg2017007
# Passing tlg4138090
# Passing tlg4138061
# Passing tlg4138117
# Passing tlg2800005
# Passing tlg4138062
# Passing tlg2062056
# Passing tlg2800004
# Passing tlg4138120
# Passing tlg4139034
# Passing tlg4138034
# Passing tlg2040038
# Passing tlg4138022
# Passing tlg4138075
# Passing tlg4090031
# Passing tlg4138003
# Passing tlg2062091
# Passing tlg2914006
# Passing tlg2035040
# Passing tlg4138145
# Passing tlg2062094
# Passing tlg2017059
# Passing tlg2040032
# Passing tlg4110007
# Passing tlg2062169
# Passing tlg2021004
# Passing tlg2062093
# Passing tlg2914009
# Passing tlg4138030
# Passing tlg2040047
# Passing tlg4138021
# Passing tlg2797038
# Passing tlg2865005
# Passing tlg4138029
# Passing tlg2914004
# Passing tlg2797028
# Passing tlg2934021
# Passing tlg4138010
# Passing tlg4138123
# Passing tlg2017020
# Passing tlg2860002
# Passing tlg2062090
# Passing tlg2022007
# Passing tlg4090117
# Passing tlg4090118
# Passing tlg2062040
# Passing tlg4138014
# Passing tlg2040055
# Passing tlg2062089
# Passing tlg2914008
# Passing tlg4138072
# Passing tlg2062041
# Passing tlg1447003
# Passing tlg2022051
# Passing tlg2062039
# Passing tlg2035039
# Passing tlg2035050
# Passing tlg2062042
# Passing tlg2035045
# Passing tlg2062031
# Passing tlg1346001
# Passing tlg2934001
# Passing tlg2040021
# Passing tlg2062175
# Passing tlg2062170
# Passing tlg2022042
# Passing tlg4138149
# Passing tlg2914005
# Passing tlg2914014
# Passing tlg4138126
# Passing tlg4138064
# Passing tlg2062379
# Passing tlg2797041
# Passing tlg2017064
# Passing tlg2062058
# Passing tlg4138042
# Passing tlg1447007
# Passing tlg2022033
# Passing tlg2934013
# Passing tlg2062081
# Passing tlg2934055
# Passing tlg2112009
# Passing tlg2017065
# Passing tlg2017021
# Passing tlg4110010
# Passing tlg2018039
# Passing tlg2914003
# Passing tlg2022044
# Passing tlg2062043
# Passing tlg2816001
# Passing tlg2017025
# Passing tlg2040036
# Passing tlg4138033
# Passing tlg2022030
# Passing tlg2110001
# Passing tlg4138007
# Passing tlg4138039
# Passing tlg4138092
# Passing tlg4138154
# Passing tlg2110006
# Passing tlg2022036
# Passing tlg4138099
# Passing tlg2892110
# Passing tlg2110011
# Passing tlg4138059
# Passing tlg2062046
# Passing tlg2040027
# Passing tlg2062178
# Passing tlg2062067
# Passing tlg2816003
# Passing tlg2816005
# Passing tlg2062496
# Passing tlg2062099
# Passing tlg2040035
# Passing tlg4138106
# Passing tlg2040045
# Passing tlg2797034
# Passing tlg2035006
# Passing tlg2017001
# Passing tlg2062381
# Passing tlg4138143
# Passing tlg2962004
# Passing tlg2062173
# Passing tlg4138132
# Passing tlg2062054
# Passing tlg4138052
# Passing tlg2017022
# Passing tlg2062019
# Passing tlg2021038
# Passing tlg2017067
# Passing tlg2017012
# Passing tlg2040007
# Passing tlg2797036
# Passing tlg2914002
# Passing tlg2062057
# Passing tlg3173001
# Passing tlg4139067
# Passing tlg2062083
# Passing tlg4138063
# Passing tlg2914015
# Passing tlg1447002
# Passing tlg2017060
# Passing tlg2017023
# Passing tlg2017076
# Passing tlg2040059
# Passing tlg2062001
# Passing tlg2017002
# Passing tlg2062050
# Passing tlg2040034
# Passing tlg2022028
# Passing tlg2062181
# Passing tlg2040005
# Passing tlg2062045
# Passing tlg4090148
# Passing tlg4138135
# Passing tlg2062380
# Passing tlg2022032
# Passing tlg2017010
# Passing tlg2040030
# Passing tlg2816007
# Passing tlg4110023
# Passing tlg4138097
# Passing tlg2062171
# Passing tlg2040022
# Passing tlg2115049
# Passing tlg2040026
# Passing tlg2035110
# Passing tlg2062176
# Passing tlg2022041
# Passing tlg2021031
# Passing tlg2714001
# Passing tlg2040020
# Passing tlg4138032
# Passing tlg2062071
# Passing tlg2062014
# Passing tlg3159001
# Passing tlg2022035
# Passing tlg2040039
# Passing tlg2914011
# Passing tlg4138035
# Passing tlg2022046
# Passing tlg2062172
# Passing tlg2040006
# Passing tlg2018030
# Passing tlg2040058
# Passing tlg2062179
# Passing tlg4089034
# Passing tlg2062074
# Passing tlg2035049
# Passing tlg4090020
# Passing tlg2062035
# Passing tlg2914012
# Passing tlg4138129
# Passing tlg2042013
# Passing tlg2022049
# Passing tlg2062029
# Passing tlg2112007
# Passing tlg2022037
# Passing tlg2062032
# Passing tlg2018029
# Passing tlg2934059
# Passing tlg2062151
# Passing tlg2017011
# Passing tlg2040029
# Passing tlg2062066
# Passing tlg2062077
# Passing tlg2062051
# Passing tlg2062149
# Passing tlg2022047
# Passing tlg2017040
# Passing tlg4138125
# Passing tlg2797048
# Passing tlg2062053
# Passing tlg2022039
# Passing tlg4138053
# Passing tlg2062145
# Passing tlg4090119
# Passing tlg4138054
# Passing tlg2062080
# Passing tlg2017005
# Passing tlg2062036
# Passing tlg2112005
# Passing tlg2062044
# Passing tlg2017003
# Passing tlg2062022
# Passing tlg2062016
# Passing tlg2062062
# Passing tlg2062020
# Passing tlg2040023
# Passing tlg4139087
# Passing tlg2598009
# Passing tlg2040043
# Passing tlg2040024
# Passing tlg4138004
# Passing tlg2022045
# Passing tlg2062070
# Passing tlg2062011
# Passing tlg2040008
# Passing tlg2022038
# Passing tlg4138122
# Passing tlg2062055
# Passing tlg4138047
# Passing tlg4138142
# Passing tlg2022021
# Passing tlg2062078
# Passing tlg2062047
# Passing tlg2022002
# Passing tlg2062180
# Passing tlg2115002
# Passing tlg2062082
# Passing tlg2042028
# Passing tlg4138025
# Passing tlg4138050
# Passing tlg1447008
# Passing tlg2040025
# Passing tlg2102012
# Passing tlg2035044
# Passing tlg2017014
# Passing tlg2022029
# Passing tlg2040037
# Passing tlg2816006
# Passing tlg2017062
# Passing tlg2017066
# Passing tlg2022020
# Passing tlg4110024
# Passing tlg2062177
# Passing tlg2062033
# Passing tlg2062010
# Passing tlg2040002
# Passing tlg2062018
# Passing tlg2062075
# Passing tlg2598008
# Passing tlg2062028
# Passing tlg2022009
# Passing tlg2062148
# Passing tlg2934009
# Passing tlg2022010
# Passing tlg2062073
# Passing tlg4138024
# Passing tlg2017049
# Passing tlg0555005
# Passing tlg2063006
# Passing tlg4138001
# Passing tlg2018031
# Passing tlg4138144
# Passing tlg4090021
# Passing tlg2062048
# Passing tlg2042045
# Passing tlg2017081
# Passing tlg4110001
# Passing tlg4138113
# Passing tlg4138051
# Passing tlg4139081
# Passing tlg2022005
# Passing tlg2062015
# Passing tlg2042018
# Passing tlg2062005
# Passing tlg2022050
# Passing tlg2017015
# Passing tlg2042039
# Passing tlg2807001
# Passing tlg2062061
# Passing tlg4138156
# Passing tlg2934054
# Passing tlg4138049
# Passing tlg4138028
# Passing tlg2035012
# Passing tlg4138153
# Passing tlg2865004
# Passing tlg2017068
# Passing tlg2017048
# Passing tlg2022011
# Passing tlg2102030
# Passing tlg2062068
# Passing tlg2017016
# Passing tlg4139072
# Passing tlg2022040
# Passing tlg2062034
# Passing tlg2934060
# Passing tlg2040028
# Passing tlg2892111
# Passing tlg2062063
# Passing tlg2022052
# Passing tlg2017083
# Passing tlg2017082
# Passing tlg3173002
# Passing tlg4138155
# Passing tlg2022057
# Passing tlg2860003
# Passing tlg2062079
# Passing tlg4110022
# Passing tlg2102014
# Passing tlg4138124
# Passing tlg2022034
# Passing tlg4138152
# Passing tlg2062084
# Passing tlg2062037
# Passing tlg2934056
# Passing tlg2035004
# Passing tlg2041005
# Passing tlg2022008
# Passing tlg2934011
# Passing tlg2934010
# Passing tlg4090030
# Passing tlg2059001
# Passing tlg2022019
# Passing tlg2062167
# Passing tlg2017006
# Passing tlg2062072
# Passing tlg2017026
# Passing tlg2062004
# Passing tlg2035059
# Passing tlg2035041
# Passing tlg4138026
# Passing tlg2062144
# Passing tlg2022027
# Passing tlg4089020
# Passing tlg2115033
# Passing tlg2062025
# Passing tlg4110020
# Passing tlg2062008
# Passing tlg2062086
# Passing tlg2021033
# Passing tlg2035011
# Passing tlg4089005
# Passing tlg2062069
# Passing tlg2062030
# Passing tlg4138134
# Passing tlg4138008
# Passing tlg2017041
# Passing tlg2892112
# Passing tlg2017024
# Passing tlg2062007
# Passing tlg2022031
# Passing tlg2062378
# Passing tlg0555006
# Passing tlg2063001
# Passing tlg2017009
# Passing tlg2734020
# Passing tlg2734005
# Passing tlg1271001
# Passing tlg2115036
# Passing tlg4138073
# Passing tlg2115003
# Passing tlg2018017
# Passing tlg4138031
# Passing tlg2022048
# Passing tlg2934006
# Passing tlg2112011
# Passing tlg4138005
# Passing tlg2022059
# Passing tlg2892049
# Passing tlg4138100
# Passing tlg2062060
# Passing tlg2018028
# Passing tlg4089021
# Passing tlg2102005
# Passing tlg2022062
# Passing tlg4138133
# Passing tlg2018021
# Passing tlg2042016
# Passing tlg2734004
# Passing tlg2022004
# Passing tlg4139038
# Passing tlg2042038
# Passing tlg2062150
# Passing tlg2042007
# Passing tlg4117001
# Passing tlg3100002
# Passing tlg4090026
# Passing tlg2062076
# Passing tlg2062026
# Passing tlg2934007
# Passing tlg2017069
# Passing tlg2042002
# Passing tlg2934008
# Passing tlg2042036
# Passing tlg2102048
# Passing tlg2042020
# Passing tlg2062002
# Passing tlg2062115
# Passing tlg2022016
# Passing tlg2017078
# Passing tlg2062163
# Passing tlg4138006
# Passing tlg4110028
# Passing tlg2102002
# Passing tlg4138076
# Passing tlg2934012
# Passing tlg2017047
# Passing tlg2806001
# Passing tlg2062486
# Passing tlg2102006
# Passing tlg2865003
# Passing tlg2062166
# Passing tlg2102007
# Passing tlg2022006
# Passing tlg2018011
# Passing tlg2062373
# Passing tlg2018007
# Passing tlg2102011
# Passing tlg2035001
# Passing tlg2022018
# Passing tlg2062065
# Passing tlg2035009
# Passing tlg2035047
# Passing tlg2017033
# Passing tlg2892008
# Passing tlg2062498
# Passing tlg2102003
# Passing tlg2062114
# Passing tlg2102047
# Passing tlg2018022
# Passing tlg2062064
# Passing tlg2734001
# Passing tlg2017043
# Passing tlg2035010
# Passing tlg2035002
# Passing tlg2102004
# Passing tlg2035043
# Passing tlg2035003
# Passing tlg2062087
# Passing tlg2017046
# Passing tlg2040052
# Passing tlg2062012
# Passing tlg4089006
# Passing tlg2062113
# Passing tlg1447001
# Passing tlg2017053
# Passing tlg2042029
# Passing tlg4090027
# Passing tlg2040048
# Passing tlg4090176
# Passing tlg2017031
# Passing tlg0555001
# Passing tlg2102001
# Passing tlg2017056
# Passing tlg4089007
# Passing tlg2102017
# Passing tlg2042009
# Passing tlg2598005
# Passing tlg2102016
# Passing tlg4090029
# Passing tlg2062382
# Passing tlg2102020
# Passing tlg2040003
# Passing tlg2035005
# Passing tlg2017008
# Passing tlg2084001
# Passing tlg2017079
# Passing tlg2042008
# Passing tlg2865002
# Passing tlg2950001
# Passing tlg4083004
# Passing tlg2022061
# Passing tlg2040051
# Passing tlg2062165
# Passing tlg2062088
# Passing tlg2017042
# Passing tlg2934005
# Passing tlg2062158
# Passing tlg2017029
# Passing tlg2062009
# Passing tlg2892002
# Passing tlg2062085
# Passing tlg2042021
# Passing tlg2062027
# Passing tlg2062003
# Passing tlg2040050
# Passing tlg2062006
# Passing tlg2102019
# Passing tlg2115030
# Passing tlg2062162
# Passing tlg2111004
# Passing tlg2040001
# Passing tlg4089025
# Passing tlg2017027
# Passing tlg0743001
# Passing tlg2062497
# Passing tlg2022060
# Passing tlg4138036
# Passing tlg2018020
# Passing tlg2062023
# Passing tlg2021001
# Passing tlg4089031
# Passing tlg2598002
# Passing tlg2062161
# Passing tlg2022001
# Passing tlg2018009
# Passing tlg2060001
# Passing tlg4089032
# Passing tlg2062021
# Passing tlg2102018
# Passing tlg2062164
# Passing tlg2040019
# Passing tlg2062097
# Passing tlg2062505
# Passing tlg4089023
# Passing tlg2040075
# Passing tlg4089004
# Passing tlg2062160
# Passing tlg4089026
# Passing tlg2040018
# Passing tlg2018023
# Passing tlg4089028
# Passing tlg4089002
# Passing tlg0555002
# Passing tlg2042079
# Passing tlg2061001
# Passing tlg2934004
# Passing tlg2102041
# Passing tlg2042019
# Passing tlg4105001
# Passing tlg4089001
# Passing tlg4089022
# Passing tlg4083006
# Passing tlg4089003
# Passing tlg2800002
# Passing tlg2110003
# Passing tlg2062159
# Passing tlg2115060
# Passing tlg2865001
# Passing tlg2035042
# Passing tlg3086012
# Passing tlg2017032
# Passing tlg4089029
# Passing tlg2892001
# Passing tlg4089027
# Passing tlg3100001
# Passing tlg2042030
# Passing tlg2042005
# Passing tlg2102010
# Passing tlg2062157
# Passing tlg2062024
# Passing tlg4090108
# Passing tlg4090023
# Passing tlg2035061
# Passing tlg2018002
# Passing tlg2062168
# Passing tlg4089008
# Passing tlg4090100
# Passing tlg2048001
# Passing tlg4090032
# Passing tlg4090109
# Passing tlg2040004
# Passing tlg2062155
# Passing tlg4090097
# Passing tlg4089030
# Passing tlg2018005
# Passing tlg2018019
# Passing tlg3094001
# Passing tlg0555004
# Passing tlg2042001
# Passing tlg2017030
# Passing tlg2598004
# Passing tlg2062156
# Passing tlg2062154
# Passing tlg0612001
# Passing tlg4089024
# Passing tlg2062143
# Passing tlg2734013
# Passing tlg4090096
# Passing tlg2714002
# Passing tlg2062153
# Passing tlg2018001
# Passing tlg2062112
# Passing tlg2018034
# Passing tlg4090001
# Passing tlg4090103
# Passing tlg2062152
# Passing tlg2021002
# Passing tlg4090002
# Passing tlg4083003
# Passing tlg4083001
# 700it [00:00, 26084.68it/s]
